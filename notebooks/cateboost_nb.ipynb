# %%
import catboost as cb

# import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# import shap
from catboost import CatBoostClassifier, Pool
# from catboost import Pool
# from sklearn.datasets import fetch_openml
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
def find_leaf_paths(tree, node, current_path, all_paths):
    current_path.append(node)

    if node not in tree or not tree[node]:  # This is a leaf node
        all_paths.append(current_path.copy())
    else:
        for child in tree[node]:
            find_leaf_paths(tree, child, current_path, all_paths)

    current_path.pop()  # Backtrack to explore other paths

def get_all_leaf_paths(tree, root):
    all_paths = []
    find_leaf_paths(tree, root, [], all_paths)
    return all_paths

# def _plot_oblivious_tree(self, splits, leaf_values):
#         graph = {}

#         layer_size = 1
#         current_size = 0

#         for split_num in range(len(splits) - 1, -2, -1):
#             for node_num in range(layer_size):
#                 graph[current_size] = 
#                 if split_num >= 0:
#                     node_label = splits[split_num].replace('bin=', 'value>', 1).replace('border=', 'value>', 1)
#                     color = 'black'
#                     shape = 'ellipse'
#                     graph[current_size][1] = node_label
#                 else:
#                     node_label = leaf_values[node_num]
#                     color = 'red'
#                     shape = 'rect'
#                     graph[current_size][1] = node_label

#                 try:
#                     graph[current_size][1] = graph[current_size][1].decode("utf-8")
#                 except Exception:
#                     pass

#                 graph[current_size][0].append()
#                 graph.node(str(current_size), node_label, color=color, shape=shape)

#                 if current_size > 0:
#                     parent = (current_size - 1) // 2
#                     edge_label = 'Yes' if current_size % 2 == 0 else 'No'
#                     graph.edge(str(parent), str(current_size), edge_label)

#                 current_size += 1

#             layer_size *= 2

#         return graph

# %%
num_samples = 3_000

data = pd.DataFrame({
    'Gender': np.random.choice(['Male', 'Female', 'Other'], num_samples),
    'Occupation': np.random.choice(['Doctor', 'Engineer', 'Teacher', 'Artist'], num_samples),
    'Age': np.random.randint(20, 60, num_samples),
    'Income': np.random.randint(30000, 100000, num_samples),
    'Label': np.random.choice([0, 1], num_samples)
})

# Define categorical features
categorical_features = ['Gender', 'Occupation']

X = data.drop(columns='Label')
y = label=data['Label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=5)

# Convert to Pool
train_dataset = Pool(X_train, y_train, cat_features=categorical_features)
test_dataset = Pool(X_test, y_test, cat_features=categorical_features)

# %%
# Train CatBoost model
model = CatBoostClassifier(iterations=1, depth=4, learning_rate=0.1, loss_function='Logloss', verbose=False)
# model.fit(train_dataset)

grid = {'iterations': [1],
        'learning_rate': [0.03, 0.1, 1],
        'depth': [2, 4, 6, 8, 10],
        'l2_leaf_reg': [0.2, 0.5, 1, 3]}

model.grid_search(grid, train_dataset)

print(model.get_all_params())
# Out:
# bestTest = 0.6931752807
# bestIteration = 0
#
# 0:	loss: 0.6931753	best: 0.6931753 (0)	total: 85.9ms	remaining: 5.07s
#
# bestTest = 0.6932569057
# bestIteration = 0
#
# 1:	loss: 0.6932569	best: 0.6931753 (0)	total: 89.1ms	remaining: 2.58s
#
# bestTest = 0.6962906269
# bestIteration = 0
#
# 2:	loss: 0.6962906	best: 0.6931753 (0)	total: 92ms	remaining: 1.75s
#
# bestTest = 0.6931752743
# bestIteration = 0
#
# 3:	loss: 0.6931753	best: 0.6931753 (3)	total: 95.5ms	remaining: 1.34s
#
# bestTest = 0.6932568831
# bestIteration = 0
#
# 4:	loss: 0.6932569	best: 0.6931753 (3)	total: 97.8ms	remaining: 1.07s
#
# bestTest = 0.6962902174
# bestIteration = 0
#
# 5:	loss: 0.6962902	best: 0.6931753 (3)	total: 100ms	remaining: 901ms
#
# bestTest = 0.6931752724
# bestIteration = 0
#
# 6:	loss: 0.6931753	best: 0.6931753 (6)	total: 103ms	remaining: 780ms
#
# bestTest = 0.6932568763
# bestIteration = 0
#
# 7:	loss: 0.6932569	best: 0.6931753 (6)	total: 105ms	remaining: 685ms
#
# bestTest = 0.6962901007
# bestIteration = 0
#
# 8:	loss: 0.6962901	best: 0.6931753 (6)	total: 109ms	remaining: 617ms
#
# bestTest = 0.693175196
# bestIteration = 0
#
# 9:	loss: 0.6931752	best: 0.6931752 (9)	total: 111ms	remaining: 557ms
#
# bestTest = 0.6932566046
# bestIteration = 0
#
# 10:	loss: 0.6932566	best: 0.6931752 (9)	total: 114ms	remaining: 506ms
#
# bestTest = 0.6962852402
# bestIteration = 0
#
# 11:	loss: 0.6962852	best: 0.6931752 (9)	total: 116ms	remaining: 465ms
#
# bestTest = 0.6932596979
# bestIteration = 0
#
# 12:	loss: 0.6932597	best: 0.6931752 (9)	total: 120ms	remaining: 435ms
#
# bestTest = 0.6936549966
# bestIteration = 0
#
# 13:	loss: 0.6936550	best: 0.6931752 (9)	total: 125ms	remaining: 409ms
#
# bestTest = 0.7099895402
# bestIteration = 0
#
# 14:	loss: 0.7099895	best: 0.6931752 (9)	total: 128ms	remaining: 384ms
#
# bestTest = 0.6932820904
# bestIteration = 0
#
# 15:	loss: 0.6932821	best: 0.6931752 (9)	total: 132ms	remaining: 363ms
#
# bestTest = 0.6936934818
# bestIteration = 0
#
# 16:	loss: 0.6936935	best: 0.6931752 (9)	total: 135ms	remaining: 342ms
#
# bestTest = 0.7082944022
# bestIteration = 0
#
# 17:	loss: 0.7082944	best: 0.6931752 (9)	total: 138ms	remaining: 322ms
#
# bestTest = 0.6933000076
# bestIteration = 0
#
# 18:	loss: 0.6933000	best: 0.6931752 (9)	total: 141ms	remaining: 304ms
#
# bestTest = 0.6937305299
# bestIteration = 0
#
# 19:	loss: 0.6937305	best: 0.6931752 (9)	total: 143ms	remaining: 286ms
#
# bestTest = 0.7070621721
# bestIteration = 0
#
# 20:	loss: 0.7070622	best: 0.6931752 (9)	total: 146ms	remaining: 271ms
#
# bestTest = 0.6932967302
# bestIteration = 0
#
# 21:	loss: 0.6932967	best: 0.6931752 (9)	total: 150ms	remaining: 259ms
#
# bestTest = 0.6936841759
# bestIteration = 0
#
# 22:	loss: 0.6936842	best: 0.6931752 (9)	total: 153ms	remaining: 246ms
#
# bestTest = 0.7031640787
# bestIteration = 0
#
# 23:	loss: 0.7031641	best: 0.6931752 (9)	total: 157ms	remaining: 236ms
#
# bestTest = 0.6932928127
# bestIteration = 0
#
# 24:	loss: 0.6932928	best: 0.6931752 (9)	total: 161ms	remaining: 225ms
#
# bestTest = 0.6937704486
# bestIteration = 0
#
# 25:	loss: 0.6937704	best: 0.6931752 (9)	total: 164ms	remaining: 214ms
#
# bestTest = 0.7116383714
# bestIteration = 0
#
# 26:	loss: 0.7116384	best: 0.6931752 (9)	total: 167ms	remaining: 205ms
#
# bestTest = 0.6933152051
# bestIteration = 0
#
# 27:	loss: 0.6933152	best: 0.6931752 (9)	total: 171ms	remaining: 196ms
#
# bestTest = 0.6938089334
# bestIteration = 0
#
# 28:	loss: 0.6938089	best: 0.6931752 (9)	total: 176ms	remaining: 188ms
#
# bestTest = 0.7099432271
# bestIteration = 0
#
# 29:	loss: 0.7099432	best: 0.6931752 (9)	total: 181ms	remaining: 181ms
#
# bestTest = 0.6933331128
# bestIteration = 0
#
# 30:	loss: 0.6933331	best: 0.6931752 (9)	total: 186ms	remaining: 174ms
#
# bestTest = 0.6938459479
# bestIteration = 0
#
# 31:	loss: 0.6938459	best: 0.6931752 (9)	total: 190ms	remaining: 166ms
#
# bestTest = 0.7087104729
# bestIteration = 0
#
# 32:	loss: 0.7087105	best: 0.6931752 (9)	total: 195ms	remaining: 159ms
#
# bestTest = 0.6932744944
# bestIteration = 0
#
# 33:	loss: 0.6932745	best: 0.6931752 (9)	total: 199ms	remaining: 152ms
#
# bestTest = 0.6936164318
# bestIteration = 0
#
# 34:	loss: 0.6936164	best: 0.6931752 (9)	total: 203ms	remaining: 145ms
#
# bestTest = 0.7031430607
# bestIteration = 0
#
# 35:	loss: 0.7031431	best: 0.6931752 (9)	total: 207ms	remaining: 138ms
#
# bestTest = 0.6934085631
# bestIteration = 0
#
# 36:	loss: 0.6934086	best: 0.6931752 (9)	total: 214ms	remaining: 133ms
#
# bestTest = 0.6941922216
# bestIteration = 0
#
# 37:	loss: 0.6941922	best: 0.6931752 (9)	total: 217ms	remaining: 126ms
#
# bestTest = 0.7180972716
# bestIteration = 0
#
# 38:	loss: 0.7180973	best: 0.6931752 (9)	total: 222ms	remaining: 119ms
#
# bestTest = 0.6934028267
# bestIteration = 0
#
# 39:	loss: 0.6934028	best: 0.6931752 (9)	total: 226ms	remaining: 113ms
#
# bestTest = 0.6941233684
# bestIteration = 0
#
# 40:	loss: 0.6941234	best: 0.6931752 (9)	total: 231ms	remaining: 107ms
#
# bestTest = 0.7146652551
# bestIteration = 0
#
# 41:	loss: 0.7146653	best: 0.6931752 (9)	total: 235ms	remaining: 101ms
#
# bestTest = 0.6933989583
# bestIteration = 0
#
# 42:	loss: 0.6933990	best: 0.6931752 (9)	total: 240ms	remaining: 94.9ms
#
# bestTest = 0.6940788748
# bestIteration = 0
#
# 43:	loss: 0.6940789	best: 0.6931752 (9)	total: 245ms	remaining: 89.1ms
#
# bestTest = 0.7120898666
# bestIteration = 0
#
# 44:	loss: 0.7120899	best: 0.6931752 (9)	total: 249ms	remaining: 83.2ms
#
# bestTest = 0.6932685483
# bestIteration = 0
#
# 45:	loss: 0.6932685	best: 0.6931752 (9)	total: 253ms	remaining: 77ms
#
# bestTest = 0.6936005246
# bestIteration = 0
#
# 46:	loss: 0.6936005	best: 0.6931752 (9)	total: 257ms	remaining: 71.1ms
#
# bestTest = 0.7034100553
# bestIteration = 0
#
# 47:	loss: 0.7034101	best: 0.6931752 (9)	total: 262ms	remaining: 65.5ms
#
# bestTest = 0.6932538043
# bestIteration = 0
#
# 48:	loss: 0.6932538	best: 0.6931752 (9)	total: 269ms	remaining: 60.5ms
#
# bestTest = 0.6936220113
# bestIteration = 0
#
# 49:	loss: 0.6936220	best: 0.6931752 (9)	total: 276ms	remaining: 55.3ms
#
# bestTest = 0.7099378663
# bestIteration = 0
#
# 50:	loss: 0.7099379	best: 0.6931752 (9)	total: 283ms	remaining: 49.9ms
#
# bestTest = 0.6932775495
# bestIteration = 0
#
# 51:	loss: 0.6932775	best: 0.6931752 (9)	total: 289ms	remaining: 44.5ms
#
# bestTest = 0.6936703195
# bestIteration = 0
#
# 52:	loss: 0.6936703	best: 0.6931752 (9)	total: 296ms	remaining: 39.1ms
#
# bestTest = 0.7083071378
# bestIteration = 0
#
# 53:	loss: 0.7083071	best: 0.6931752 (9)	total: 302ms	remaining: 33.5ms
#
# bestTest = 0.693295857
# bestIteration = 0
#
# 54:	loss: 0.6932959	best: 0.6931752 (9)	total: 310ms	remaining: 28.2ms
#
# bestTest = 0.693713498
# bestIteration = 0
#
# 55:	loss: 0.6937135	best: 0.6931752 (9)	total: 318ms	remaining: 22.7ms
#
# bestTest = 0.7072269312
# bestIteration = 0
#
# 56:	loss: 0.7072269	best: 0.6931752 (9)	total: 326ms	remaining: 17.1ms
#
# bestTest = 0.6933857064
# bestIteration = 0
#
# 57:	loss: 0.6933857	best: 0.6931752 (9)	total: 333ms	remaining: 11.5ms
#
# bestTest = 0.6939906594
# bestIteration = 0
#
# 58:	loss: 0.6939907	best: 0.6931752 (9)	total: 341ms	remaining: 5.79ms
#
# bestTest = 0.7076084565
# bestIteration = 0
#
# 59:	loss: 0.7076085	best: 0.6931752 (9)	total: 348ms	remaining: 0us
# Estimating final quality...
# Training on fold [0/3]
#
# bestTest = 0.6930257367
# bestIteration = 0
#
# Training on fold [1/3]
#
# bestTest = 0.6932690797
# bestIteration = 0
#
# Training on fold [2/3]
#
# bestTest = 0.6931385478
# bestIteration = 0
#
# {'nan_mode': 'Min', 'eval_metric': 'Logloss', 'combinations_ctr': ['Borders:CtrBorderCount=15:CtrBorderType=Uniform:TargetBorderCount=1:TargetBorderType=MinEntropy:Prior=0/1:Prior=0.5/1:Prior=1/1', 'Counter:CtrBorderCount=15:CtrBorderType=Uniform:Prior=0/1'], 'iterations': 1, 'sampling_frequency': 'PerTree', 'fold_permutation_block': 0, 'leaf_estimation_method': 'Newton', 'random_score_type': 'NormalWithModelSizeDecrease', 'counter_calc_method': 'SkipTest', 'grow_policy': 'SymmetricTree', 'penalties_coefficient': 1, 'boosting_type': 'Plain', 'model_shrink_mode': 'Constant', 'feature_border_type': 'GreedyLogSum', 'ctr_leaf_count_limit': 18446744073709551615, 'bayesian_matrix_reg': 0.10000000149011612, 'one_hot_max_size': 2, 'eval_fraction': 0, 'force_unit_auto_pair_weights': False, 'l2_leaf_reg': 3, 'random_strength': 1, 'rsm': 1, 'boost_from_average': False, 'max_ctr_complexity': 1, 'model_size_reg': 0.5, 'simple_ctr': ['Borders:CtrBorderCount=15:CtrBorderType=Uniform:TargetBorderCount=1:TargetBorderType=MinEntropy:Prior=0/1:Prior=0.5/1:Prior=1/1', 'Counter:CtrBorderCount=15:CtrBorderType=Uniform:Prior=0/1'], 'pool_metainfo_options': {'tags': {}}, 'subsample': 0.800000011920929, 'use_best_model': False, 'class_names': [0, 1], 'random_seed': 0, 'depth': 2, 'ctr_target_border_count': 1, 'posterior_sampling': False, 'has_time': False, 'store_all_simple_ctr': False, 'border_count': 254, 'classes_count': 0, 'auto_class_weights': 'None', 'sparse_features_conflict_fraction': 0, 'leaf_estimation_backtracking': 'AnyImprovement', 'best_model_min_trees': 1, 'model_shrink_rate': 0, 'min_data_in_leaf': 1, 'loss_function': 'Logloss', 'learning_rate': 0.029999999329447743, 'score_function': 'Cosine', 'task_type': 'CPU', 'leaf_estimation_iterations': 1, 'bootstrap_type': 'MVS', 'max_leaves': 4, 'permutation_count': 4}

# %%
print("\n SECTION BREAK --------------")
pred = model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(y_test, pred)))
r2 = r2_score(y_test, pred)
print("Testing performance")
print("RMSE: {:.2f}".format(rmse))
print("R2: {:.2f}".format(r2))

# %%
tree_model = model.plot_tree(tree_idx=0, pool=train_dataset)

print(model.get_tree_leaf_counts)
print(model._get_tree_splits(0, train_dataset))
print(model._get_tree_leaf_values(0))
# print(model._get_tree_node_to_leaf(0))

tree_model.save("./examples/tree.dot")
model.save_model("./examples/model.json", format="json")
model.save_borders("./examples/borders")
# pool, _ = self._process_predict_input_data(pool, "plot_tree", thread_count=-1) if pool is not None else (None, None)

#         splits = self._get_tree_splits(tree_idx, pool)
#         leaf_values = self._get_tree_leaf_values(tree_idx)
#         if self._object._is_oblivious():
#             return self._plot_oblivious_tree(splits, leaf_values)
#         else:
#             step_nodes = self._get_tree_step_nodes(tree_idx)
#             node_to_leaf = self._get_tree_node_to_leaf(tree_idx)
#             return self._plot_nonsymmetric_tree(splits, leaf_values, step_nodes, node_to_leaf)
